# %% [markdown]
# Task - 1

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

print("Gymnasium Version:", gym.__version__)
# Out:
# Gymnasium Version: 1.1.1

# %% [markdown]
# Task - 2

# %%
import gymnasium as gym


env = gym.make("CartPole-v1")


observation, info = env.reset()

print("Initial Observation:")
print(observation)

print("\nEnvironment Info:")
print(info)
# Out:
# Initial Observation:
# [ 0.00040509  0.01127484 -0.0328642  -0.03011545]
#
# Environment Info:
# {}

# %% [markdown]
# Task - 3

# %%
import gymnasium as gym

env = gym.make("CartPole-v1")

observation, info = env.reset()

print("Initial Observation:")
print(observation)

print("\nEnvironment Info:")
print(info)

print("\nObservation Space:")
print(env.observation_space)

print("\nAction Space:")
print(env.action_space)

print("\nObservation Space Type:")
print(type(env.observation_space))

print("\nNumber of Possible Actions:")
print(env.action_space.n)
# Out:
# Initial Observation:
# [-0.0235572  -0.04018767 -0.04101782  0.04780161]
#
# Environment Info:
# {}
#
# Observation Space:
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
#
# Action Space:
# Discrete(2)
#
# Observation Space Type:
# <class 'gymnasium.spaces.box.Box'>
#
# Number of Possible Actions:
# 2

# %% [markdown]
# Task - 4

# %%
import gymnasium as gym

# Create the CartPole environment
env = gym.make("CartPole-v1")

# Reset the environment
observation, info = env.reset()

# Initialize counters
step = 0
total_reward = 0

print("Starting Random Agent...\n")

# Run one episode
while True:

    # Select a random action
    action = env.action_space.sample()

    # Execute the action
    observation, reward, terminated, truncated, info = env.step(action)

    # Update counters
    step += 1
    total_reward += reward

    # Print step details
    print(f"Step: {step}")
    print(f"Action: {action}")
    print(f"Observation: {observation}")
    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}")
    print(f"Truncated: {truncated}")
    print("-" * 40)

    # End the episode if finished
    if terminated or truncated:
        break

print("\nEpisode Finished!")
print(f"Total Steps: {step}")
print(f"Total Reward: {total_reward}")

# Close the environment
env.close()
# Out:
# Starting Random Agent...
#
# Step: 1
# Action: 1
# Observation: [-0.04828697  0.18795209 -0.04118809 -0.27073267]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 2
# Action: 0
# Observation: [-0.04452793 -0.00655865 -0.04660275  0.00868011]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 3
# Action: 1
# Observation: [-0.0446591   0.1891996  -0.04642915 -0.29833472]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 4
# Action: 1
# Observation: [-0.04087511  0.38495156 -0.05239584 -0.6052915 ]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 5
# Action: 1
# Observation: [-0.03317608  0.58076555 -0.06450167 -0.9140067 ]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 6
# Action: 1
# Observation: [-0.02156076  0.7766979  -0.08278181 -1.2262444 ]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 7
# Action: 1
# Observation: [-0.00602681  0.97278225 -0.10730669 -1.5436738 ]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 8
# Action: 0
# Observation: [ 0.01342884  0.779101   -0.13818017 -1.2863107 ]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 9
# Action: 0
# Observation: [ 0.02901086  0.58598137 -0.16390638 -1.0398881 ]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 10
# Action: 0
# Observation: [ 0.04073049  0.3933713  -0.18470414 -0.80281824]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 11
# Action: 0
# Observation: [ 0.04859791  0.20119725 -0.20076051 -0.5734551 ]
# Reward: 1.0
# Terminated: False
# Truncated: False
# ----------------------------------------
# Step: 12
# Action: 0
# Observation: [ 0.05262186  0.00937194 -0.21222961 -0.35012415]
# Reward: 1.0
# Terminated: True
# Truncated: False
# ----------------------------------------
#
# Episode Finished!
# Total Steps: 12
# Total Reward: 12.0
